# %%
import numpy as np # renaming of the library for shortcut 
import pandas as pd

# %%
da = pd.read_csv(  "/content/titanic.csv" )
da.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
da.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
da.shape
# Out:
# (891, 12)

# %%
# Print the name of all the columns.
list(da.columns.values)
#sorted(da)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
last_column = da.iloc[ : , -1]
print(last_column.name)# to get the name of column
print(last_column) # to get the values in the column
# Out:
# Embarked
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
print(da['Sex'].dtypes)
# Out:
# object

# %%
da['Embarked'].nunique()
# Out:
# 3

# %%
da['Embarked'].value_counts() # s is the most frequent
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
da.describe() # to get mean , st and percentages
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Data preparation

# %%
#da[da['Sex'] == 'male']
df =da.query("Age >= 20")
print (df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(by=['Age','Survived'])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 12            13         0       3        Saundercock, Mr. William Henry
# 91            92         0       3            Andreasson, Mr. Paul Edvin
# 113          114         0       3               Jussila, Miss. Katriina
# 131          132         0       3        Coelho, Mr. Domingos Fernandeo
# 378          379         0       3                   Betros, Mr. Tannous
# ..           ...       ...     ...                                   ...
# 116          117         0       3                  Connors, Mr. Patrick
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 851          852         0       3                   Svensson, Mr. Johan
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
df[df.Name.str.contains("Y")]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 199          200         0       2   Yrois, Miss. Henriette ("Mrs Harbeck")
# 203          204         0       3                     Youseff, Mr. Gerious
# 255          256         1       3  Touma, Mrs. Darwis (Hanne Youssef Razi)
# 321          322         0       3                         Danoff, Mr. Yoto
# 325          326         1       1                 Young, Miss. Marie Grice
# 620          621         0       3                      Yasbeck, Mr. Antoni
# 798          799         0       3             Ibrahim Shawah, Mr. Yousseff
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 199  female  24.0      0      0    248747   13.0000   NaN        S
# 203    male  45.5      0      0      2628    7.2250   NaN        C
# 255  female  29.0      0      2      2650   15.2458   NaN        C
# 321    male  27.0      0      0    349219    7.8958   NaN        S
# ...

# %%
#da.groupby(by='Survived').size()
df.groupby(by='Survived').describe()
# Out:
#          PassengerId                                                           \
#                count        mean         std  min    25%    50%    75%    max
# Survived
# 0              339.0  445.545723  260.414156  1.0  213.5  442.0  672.5  891.0
# 1              211.0  462.507109  243.342779  2.0  274.5  461.0  649.0  890.0
#
#          Pclass            ... Parch        Fare                             \
#           count      mean  ...   75%  max  count       mean        std  min
# Survived                   ...
# 0         339.0  2.407080  ...   0.0  6.0  339.0  22.192464  30.733934  0.0
# 1         211.0  1.734597  ...   0.5  5.0  211.0  57.034598  76.267134  0.0
#
#
#               25%    50%      75%       max
# Survived
# 0          7.8958  10.50  26.0000  263.0000
# 1         13.0000  26.55  76.7292  512.3292
#
# [2 rows x 48 columns]

# %%
da['Survived'] = da['Survived'].astype(object)
print(da['Survived'].dtypes)
# df['Survived'] = df['Survived'].astype(object)
#print(df['Survived'].dtypes)
# Out:
# object

# %%
df.groupby(by=['Sex','Pclass']) # dataset is grouped by these 2 columns

# %%
df.isnull().sum() # missing values are in cabin and embarked
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          394
# Embarked         2
# dtype: int64

# %%
 df['Age'].fillna(method='backfill').head(10) # takes the same value of the next valid
 #df['Age'].fillna(method='backfill').head(10) this is done on original dataset with null values
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 6     54.0
# 8     27.0
# 11    58.0
# 12    20.0
# 13    39.0
# Name: Age, dtype: float64

# %%
df.drop(['Cabin'], axis = 1)
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        0       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 884          885        0       3
# 885          886        0       3
# 886          887        0       2
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated().sum() # No duplicates
# Out:
# 0

# %%
pd.cut(df['Age'],8).value_counts()
# Discretize Age column into 8 groups using equal interval method and count
# Out:
# (19.94, 27.5]    173
# (27.5, 35.0]     160
# (35.0, 42.5]      88
# (42.5, 50.0]      65
# (50.0, 57.5]      31
# (57.5, 65.0]      25
# (65.0, 72.5]       6
# (72.5, 80.0]       2
# Name: Age, dtype: int64

# %%
df['Embarked'].isnull().index
# Out:
# Int64Index([  0,   1,   2,   3,   4,   6,   8,  11,  12,  13,
#             ...
#             879, 880, 881, 882, 883, 884, 885, 886, 889, 890],
#            dtype='int64', length=550)

# %%
print(df.Age.max())
# Out:
# 80.0
